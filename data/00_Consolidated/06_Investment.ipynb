# %%
# Paso 0: Importar libreria Pandas

import pandas as pd

# %%
# Paso 1: Cargar DFs con csv generados

colonial = pd.read_csv('col.csv')
merlin = pd.read_csv('mrl.csv')

# %%
# Paso 2: Concatenar los diferentes DFs para tener un consolidado de Banking

investment = pd.concat([colonial, merlin], axis=0)

investment.reset_index(drop=True)
# Out:
#       id ticker                empresa        date   open   high    low  \
# 0     23    COL  Colonial Inmobiliaria  2019-01-02  7.950  8.065  7.885
# 1     23    COL  Colonial Inmobiliaria  2019-01-03  8.020  8.085  7.990
# 2     23    COL  Colonial Inmobiliaria  2019-01-04  8.100  8.185  8.040
# 3     23    COL  Colonial Inmobiliaria  2019-01-07  8.200  8.305  8.140
# 4     23    COL  Colonial Inmobiliaria  2019-01-08  8.320  8.540  8.255
# ...   ..    ...                    ...         ...    ...    ...    ...
# 2645  27    MRL      Merlin Properties  2024-02-26  9.190  9.225  9.130
# 2646  27    MRL      Merlin Properties  2024-02-27  9.100  9.240  9.100
# 2647  27    MRL      Merlin Properties  2024-02-28  9.170  9.170  8.760
# 2648  27    MRL      Merlin Properties  2024-02-29  8.755  8.970  8.730
# 2649  27    MRL      Merlin Properties  2024-03-01  8.835  9.110  8.825
#
#       close  adj close   volume
# 0     8.020   6.861066   717693
# 1     8.040   6.878175   704526
# ...

# %%
# Paso 3: Exportar el DF a csv

investment.to_csv('investment.csv')

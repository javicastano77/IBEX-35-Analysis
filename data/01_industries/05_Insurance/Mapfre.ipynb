# %%
# Paso 0: Importar libreria Pandas

import pandas as pd

# %%
# Paso 1: Cargar DF con la info descargada

mapfre = pd.read_csv('MAP.MC.csv')

mapfre
# Out:
#             Date   Open   High    Low  Close  Adj Close   Volume
# 0     2019-01-02  2.310  2.319  2.252  2.295   1.515935  4014328
# 1     2019-01-03  2.292  2.318  2.281  2.306   1.523200  4965524
# 2     2019-01-04  2.320  2.373  2.312  2.371   1.566135  3943996
# 3     2019-01-07  2.380  2.398  2.364  2.370   1.565475  2918356
# 4     2019-01-08  2.358  2.373  2.333  2.367   1.563493  5603813
# ...          ...    ...    ...    ...    ...        ...      ...
# 1320  2024-02-26  1.958  1.977  1.956  1.970   1.970000  2029619
# 1321  2024-02-27  1.963  1.965  1.944  1.965   1.965000  1986974
# 1322  2024-02-28  1.970  1.977  1.960  1.962   1.962000  1721239
# 1323  2024-02-29  1.960  1.978  1.955  1.959   1.959000  4265819
# 1324  2024-03-01  1.970  1.981  1.963  1.974   1.974000  2207711
#
# [1325 rows x 7 columns]

# %%
# Paso 2: Insertar nuevas columnas en el DF, 'id','ticker','empresa'

mapfre['id'] = 25
mapfre['ticker'] = 'MAP'
mapfre['empresa'] = 'mapfre'

mapfre
# Out:
#             Date   Open   High    Low  Close  Adj Close   Volume  id ticker  \
# 0     2019-01-02  2.310  2.319  2.252  2.295   1.515935  4014328  25    MAP
# 1     2019-01-03  2.292  2.318  2.281  2.306   1.523200  4965524  25    MAP
# 2     2019-01-04  2.320  2.373  2.312  2.371   1.566135  3943996  25    MAP
# 3     2019-01-07  2.380  2.398  2.364  2.370   1.565475  2918356  25    MAP
# 4     2019-01-08  2.358  2.373  2.333  2.367   1.563493  5603813  25    MAP
# ...          ...    ...    ...    ...    ...        ...      ...  ..    ...
# 1320  2024-02-26  1.958  1.977  1.956  1.970   1.970000  2029619  25    MAP
# 1321  2024-02-27  1.963  1.965  1.944  1.965   1.965000  1986974  25    MAP
# 1322  2024-02-28  1.970  1.977  1.960  1.962   1.962000  1721239  25    MAP
# 1323  2024-02-29  1.960  1.978  1.955  1.959   1.959000  4265819  25    MAP
# 1324  2024-03-01  1.970  1.981  1.963  1.974   1.974000  2207711  25    MAP
#
#      empresa
# 0     mapfre
# 1     mapfre
# 2     mapfre
# 3     mapfre
# 4     mapfre
# ...      ...
# 1320  mapfre
# 1321  mapfre
# 1322  mapfre
# 1323  mapfre
# 1324  mapfre
#
# [1325 rows x 10 columns]

# %%
# Paso 3: Modificar títulos de columnas con función lower.


mapfre.columns = mapfre.columns.str.lower()

mapfre.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'adj close', 'volume', 'id',
#        'ticker', 'empresa'],
#       dtype='object')

# %%
# Paso 4: Ordenar columnas del DF

mapfre = mapfre[['id','ticker','empresa','date','open','high','low','close','adj close','volume']]

mapfre
# Out:
#       id ticker empresa        date   open   high    low  close  adj close  \
# 0     25    MAP  mapfre  2019-01-02  2.310  2.319  2.252  2.295   1.515935
# 1     25    MAP  mapfre  2019-01-03  2.292  2.318  2.281  2.306   1.523200
# 2     25    MAP  mapfre  2019-01-04  2.320  2.373  2.312  2.371   1.566135
# 3     25    MAP  mapfre  2019-01-07  2.380  2.398  2.364  2.370   1.565475
# 4     25    MAP  mapfre  2019-01-08  2.358  2.373  2.333  2.367   1.563493
# ...   ..    ...     ...         ...    ...    ...    ...    ...        ...
# 1320  25    MAP  mapfre  2024-02-26  1.958  1.977  1.956  1.970   1.970000
# 1321  25    MAP  mapfre  2024-02-27  1.963  1.965  1.944  1.965   1.965000
# 1322  25    MAP  mapfre  2024-02-28  1.970  1.977  1.960  1.962   1.962000
# 1323  25    MAP  mapfre  2024-02-29  1.960  1.978  1.955  1.959   1.959000
# 1324  25    MAP  mapfre  2024-03-01  1.970  1.981  1.963  1.974   1.974000
#
#        volume
# 0     4014328
# 1     4965524
# 2     3943996
# 3     2918356
# 4     5603813
# ...       ...
# 1320  2029619
# 1321  1986974
# 1322  1721239
# 1323  4265819
# 1324  2207711
#
# [1325 rows x 10 columns]

# %%
# Paso 5: Pasar a csv el DF

mapfre.to_csv('map.csv',index=False)
